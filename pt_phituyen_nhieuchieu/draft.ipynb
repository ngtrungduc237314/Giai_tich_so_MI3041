# %%
import sympy as sp

# Bật chế độ in công thức toán học đẹp (MathJax/LaTeX) trong Jupyter Notebook
sp.init_printing(use_latex='mathjax')

# 1. Khai báo các biến số dưới dạng ký hiệu toán học
x1, x2, x3 = sp.symbols('x1 x2 x3')

# 2. Khai báo hệ phương trình phi tuyến (Ví dụ trong slide của bạn)
f1 = 3*x1 - sp.cos(x2*x3) - 0.5
f2 = x1**2 - 81*(x2 + 0.1)**2 + sp.sin(x3) + 1.06
f3 = sp.exp(-x1*x2) + 20*x3 + 9.1389

# Tạo vector cột F
F = sp.Matrix([f1, f2, f3])

# 3. Yêu cầu máy tính đạo hàm ra dạng tổng quát của Ma trận Jacobi
J = F.jacobian([x1, x2, x3])

# 4. Hiển thị ma trận (Chỉ cần gõ tên biến J ở cuối ô cell trong Jupyter)
J
# Out:
# ⎡     3       x₃⋅sin(x₂⋅x₃)   x₂⋅sin(x₂⋅x₃)⎤
# ⎢                                          ⎥
# ⎢   2⋅x₁      -162⋅x₂ - 16.2     cos(x₃)   ⎥
# ⎢                                          ⎥
# ⎢     -x₁⋅x₂        -x₁⋅x₂                 ⎥
# ⎣-x₂⋅ℯ         -x₁⋅ℯ               20      ⎦
