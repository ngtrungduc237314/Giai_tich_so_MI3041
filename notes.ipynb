# %% [markdown]
# # TONG QUAN VE GIAI TICH SO MI3041
#
# ## 1. Quy tac ngam
# ### 1.1. Trong tinh toan khoa hoc, luon phai tinh den sai so lon nhat, tuc du phong cho truong hop sai lech xau xi nhat.
#
# ### 1.2. Doi voi dinh nghia sai so gia tri tuyet doi toi han $|a - a^* | \leq \Delta a$; neu xet chat che thi phai ton tai truong hop dau = xay ra, tuy nhien, trong thuc te, viec co gang de dau = xay ra ton chi phi va thoi gian ngang voi viec tim duoc gia tri dung $a^*$. Do do, ta co the linh hoat giua dau $\leq$ va dau $<$.
#
# ### 1.3. Sai so va vi phan co quan he mat thiet.
# VD: Cong thuc tinh gan dung dua tren vi phan trong GT1
#
# $f(x_0 + \Delta x) \approx f^{'}(x_0)\Delta x + f(x_0)$
# ### 1.4. Trong Giai tich so, de thoa man mot menh de, ta co the linh hoat dung Dieu kien du thay vi dieu kien can va du mot cach chat che nhu trong Toan ly thuyet. Ngoai ra, Dieu kien can duoc dung phu tro de loai bo cac truong hop sai.
#
# ## 2. Luu y ve sai so
# ### 2.1. Ky hieu sai so: $\varepsilon$ la ki hieu chung cho sai so, bao gom sai so tuyet doi ($\Delta x$), sai so tuong doi ($\delta x$), sai so muc tieu, ...
#
# ### 2.2. Ky hieu cho bien chay: $i, k, n, j, \dots$
#
# ### 2.3. Ky hieu cho so lan lap toi da: $N_0$
#
# ## 3. Luu y khac
# ### 3.1. Cong thuc danh gia sai so duoc xay dung dua tren cong thuc lap.
#
# ### 3.2. Cong thuc sai so hau nghiem thuong chat hon cong thuc sai so tien nghiem.
#
# ### 3.3. Sai so toan phan = sai so phuong phap (cong thuc danh gia sai so) + sai so lam tron; tuy nhien, ta thuong co tinh chon nhieu chu so sau dau phay cua nghiem gan dung de han che sai so lam tron nen thong thuong sai so toan phan = sai so phuong phap.
#
# Sai so tuyet doi lam tron = 0.5 * 10 ^ [so luong chu so thap phan cua nghiem gan dung]
#
# Sai so tuong doi lam tron = 0.5 * 10 ^ [so luong chu so thap phan cua nghiem gan dung] / |nghiem gan dung|
#
# ## 3. Luu y ve thuat toan
# ### 3.1. Tat ca cac thuat toan trong day chi ap dung de tim duoc 1 nghiem cua phuong trinh hoac he phuong trinh vi chung chi duoc ap dung tren mot khoang cach ly nghiem hoac mien cach ly nghiem tuong ung.

# %% [markdown]
# # 4. Thu vien
# **numpy** (tính toán mảng/ma trận)
#
# **sympy** (toán ký hiệu)
#
# **scipy** (đối chiếu kết quả chuẩn)
#
# **matplotlib** (vẽ đồ thị)
