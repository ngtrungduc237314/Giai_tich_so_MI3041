# %% [markdown]
# # TAI LIEU THAM KHAO
#
# ## 1. Giao trinh Phuong phap tinh
# ## 2. Slide co Yen
# ## 3. Slide FAMI phuong phap tinh (chu yeu de on tap)
# ## 4. "Numerical Analysis" – Richard L. Burden & J. Douglas Faires
