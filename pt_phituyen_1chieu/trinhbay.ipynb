# %% [markdown]
# # Cach trinh bay Chuong 2: Cac phuong phap giai gan dung phuong trinh y = f(x) trong **R**
#
# B1: Xac dinh khoang cach ly nghiem = dieu kien du hoac ve do thi
#
# B1: Kiem tra dieu kien hoi tu cua y = f(x)
#
# B2: Xac dinh dieu kien dung
#
# B3: Ap dung thuat toan
#
# B4: Danh gia sai so

# %% [markdown]
# (Khi di thi chi chep tu phan B. Thuat toan va danh gia sai so)
